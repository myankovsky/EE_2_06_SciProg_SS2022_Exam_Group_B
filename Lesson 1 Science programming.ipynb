# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt


# %matplotlib inline

# %%
df = pd.read_csv('Raw Data 2.csv')

# %%
df.head()
# Out:
#    Time (s)  Linear Acceleration x (m/s^2)  Linear Acceleration y (m/s^2)  \
# 0  0.049767                      -0.015435                       0.033814
# 1  0.059713                      -0.282244                       0.022250
# 2  0.069659                      -0.234370                      -0.090020
# 3  0.079604                      -0.122226                      -0.117186
# 4  0.089550                      -0.193365                      -0.062274
#
#    Linear Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                       0.150203                       0.154734
# 1                       0.893827                       0.937595
# 2                       0.889226                       0.923990
# 3                       0.397987                       0.432510
# 4                       0.209502                       0.291820

# %%
X = df['Time (s)']
Y = df['Linear Acceleration y (m/s^2)']

# %%
plt.figure(figsize=(16, 10), dpi= 100, facecolor='w')
plt.plot(X, Y)

# %% [markdown]
# $$
# \int x^2 \
# $$

# %%
dict = {'Time (s)': 'Time', 'Linear Acceleration x (m/s^2)': 'ax m/s^2', 'Linear Acceleration y (m/s^2)': 'ay m/s^2', 
        'Linear Acceleration z (m/s^2)': 'az, m/s^2', 'Absolute acceleration (m/s^2)': 'Abs a, m/s^2'}
 
df.rename(columns=dict, inplace=True)

# %%
display(df)
# Out:
#            Time  ax m/s^2  ay m/s^2  az, m/s^2  Abs a, m/s^2
# 0      0.049767 -0.015435  0.033814   0.150203      0.154734
# 1      0.059713 -0.282244  0.022250   0.893827      0.937595
# 2      0.069659 -0.234370 -0.090020   0.889226      0.923990
# 3      0.079604 -0.122226 -0.117186   0.397987      0.432510
# 4      0.089550 -0.193365 -0.062274   0.209502      0.291820
# ...         ...       ...       ...        ...           ...
# 2752  27.420541  0.009902 -0.167820   0.213321      0.271601
# 2753  27.430486 -0.044653 -0.114199   0.198474      0.233297
# 2754  27.440432 -0.088449 -0.156232   0.288526      0.339822
# 2755  27.450378  0.018556 -0.156045   0.422948      0.451198
# 2756  27.460324  0.288620 -0.159896  -0.006651      0.330019
#
# [2757 rows x 5 columns]
